# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("car_prices.csv")

# %%
data = df.copy()

# %%
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
data = data.dropna()

# %%
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558831  2011     BMW             5 Series         528i      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0  white
# ...

# %%
data.describe()
# Out:
#                 year      condition       odometer            mmr  \
# count  472325.000000  472325.000000  472325.000000  472325.000000
# mean     2010.210980      30.774177   66701.732040   13837.058964
# std         3.822151      13.286866   51939.586894    9532.229273
# min      1990.000000       1.000000       1.000000      25.000000
# 25%      2008.000000      24.000000   28137.000000    7425.000000
# 50%      2012.000000      35.000000   51085.000000   12300.000000
# 75%      2013.000000      41.000000   96590.000000   18300.000000
# max      2015.000000      49.000000  999999.000000  182000.000000
#
#         sellingprice
# count  472325.000000
# mean    13690.512058
# std      9613.033738
# min         1.000000
# 25%      7200.000000
# 50%     12200.000000
# 75%     18200.000000
# max    230000.000000

# %%
cars_2010 = data.loc[lambda table: table["year"] == 2010]

# %%
cars_2010
# Out:
#         year        make             model             trim      body  \
# 2465    2010   Chevrolet              Aveo              1LT     Sedan
# 2467    2010       Dodge        Challenger               SE     Coupe
# 2474    2010   Chevrolet             Tahoe               LS       SUV
# 2486    2010   Chevrolet           Equinox               LS       SUV
# 2493    2010   Chevrolet           Equinox              LTZ       SUV
# ...      ...         ...               ...              ...       ...
# 558689  2010   Chevrolet  Silverado 2500HD       Work Truck  crew cab
# 558691  2010       Mazda            Mazda6  i Grand Touring     sedan
# 558793  2010    Cadillac      Escalade ESV           Luxury       SUV
# 558801  2010     Mercury           Mariner          Premier       SUV
# 558802  2010  Volkswagen            Tiguan                S       SUV
#
#        transmission                vin state  condition  odometer   color  \
# ...

# %%
car_make_counts = cars_2010["make"].value_counts()

# %% [raw]
# car_make_counts

# %%
top_cars_2010 = dict(car_make_counts.head())

# %%
top_cars_2010
# Out:
# {'Ford': 3534, 'Chevrolet': 3347, 'Dodge': 2421, 'Toyota': 1991, 'Honda': 1313}

# %%
top_cars_2010.keys()
# Out:
# dict_keys(['Ford', 'Chevrolet', 'Dodge', 'Toyota', 'Honda'])

# %%
sns.set()
f, ax = plt.subplots(figsize=(20, 5))

bars = sns.barplot(x=list(top_cars_2010.keys()), y=list(top_cars_2010.values()), ax=ax)

ax.set_title("Top 5 Car Brands Sold in 2010")
ax.set_xlabel("Brands")
ax.set_ylabel("Cars Sold")
ax.set_ylim((0, 5000))

for bar in bars.patches:
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), 
            int(bar.get_height()), ha='center', va='bottom')

plt.show()

# %%
toyota_cars = data.loc[(data["make"] == "Ford") & (data["year"] == 2010)]

# %%
toyota_cars
# Out:
#         year  make             model        trim         body transmission  \
# 2646    2010  Ford             Focus          SE        Sedan    automatic
# 2648    2010  Ford             F-150          XL  Regular Cab    automatic
# 2649    2010  Ford  F-250 Super Duty          XL     SuperCab    automatic
# 2668    2010  Ford        Expedition  EL Limited          SUV    automatic
# 2669    2010  Ford             Focus          SE        Sedan       manual
# ...      ...   ...               ...         ...          ...          ...
# 558059  2010  Ford             F-150         XLT     supercab    automatic
# 558342  2010  Ford             F-150         XLT    supercrew    automatic
# 558531  2010  Ford            Fusion           S        sedan    automatic
# 558587  2010  Ford             F-150  SVT Raptor     supercab    automatic
# 558588  2010  Ford           Mustang  GT Premium        coupe    automatic
#
# ...

# %%
toyota_cars_counts = toyota_cars["body"].value_counts()

# %%
toyota_cars_counts
# Out:
# body
# SuperCrew       680
# SUV             656
# Sedan           577
# SuperCab        382
# supercrew       160
# suv             137
# Coupe           123
# Crew Cab        122
# Minivan          97
# Regular Cab      93
# sedan            92
# Wagon            71
# supercab         68
# Convertible      58
# coupe            44
# minivan          41
# Van              33
# crew cab         29
# regular cab      21
# wagon            20
# convertible      12
# E-Series Van      9
# van               8
# e-series van      1
# Name: count, dtype: int64

# %%
top_ford_2010 = dict(toyota_cars_counts.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 top_ford_2010 = dict(toyota_cars_counts.head())
#
# AttributeError: 'list' object has no attribute 'head'

# %%
top_ford_2010
# Out:
# {'SuperCrew': 680, 'SUV': 656, 'Sedan': 577}

# %%
sns.set()
f, ax = plt.subplots(figsize=(20, 5))

bars = sns.barplot(x=list(top_ford_2010.keys()), y=list(top_ford_2010.values()), ax=ax)

ax.set_title("Top 5 Car Brands Sold in 2010")
ax.set_xlabel("Body")
ax.set_ylabel("Cars Sold")
ax.set_ylim((0, 1000))

for bar in bars.patches:
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), 
            int(bar.get_height()), ha='center', va='bottom')

plt.show()

# %%
top_ford_2010 = [name.lower() for name in top_ford_2010]
